# %% [markdown]
# <a href="https://colab.research.google.com/github/Hoanhtai123/machin_learning/blob/main/%20SororiShinzaemon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def compute_sorori_shinzaemon(day = 100):
    """
    A function that verifies the anecdote of rice by Sorori Shinzaemon. Calculate the number of rice grains per day.
    Parameteres
    --------------
    day: int
        Number of days to get rice (default : 100)
    Returns
    --------------
    list_n_grains : list
        List of the number of rice you get one day (the length of the list is equal to day)
    list_total_grains : list
        List of the total number of rice you will receive by a certain day (the length of the list will be equal to day)
    """
    # Write the code here. pass is an instruction that means do nothing.
    list_n_grains=[1]
    #list_n_grains[0] = 1
    first_day = 1
    list_total_grains = [1]
    #list_total_grains[0] = 1;
    range_loop = range(1,100)
    for x in range_loop: 
      first_day = first_day*2
      list_n_grains.append(first_day)
      list_total_grains.append(list_n_grains[x] + list_total_grains[x-1])
    print(day)
    print(list_n_grains)
    print(list_total_grains)
    pass
    return list_n_grains, list_total_grains
list_n_grains, list_total_grains = compute_sorori_shinzaemon(day=100)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("number of rice you gain")
plt.xlabel("number of day")
plt.ylabel("number of rice")
#plt.plot(list_n_grains, list_n_grains, label='number of rice you gain a day')
plt.plot(list_n_grains, label='number of rice you gain a day') # Enter the variable name of the list in "List name"
plt.plot(list_total_grains, label='number of rice you gain')
plt.legend()
plt.show()
# Out:
# 100
# ...

# %%
Normal people need how much calories per day? https://www.nhs.uk/common-health-questions/food-and-diet/what-should-my-daily-intake-of-calories-be/#:~:text=Generally%2C%20the%20recommended%20daily%20calorie,women%20and%202%2C500%20for%20men.

--> A man need 2500 calories per day

--> A woman need 2000 calories per day

--> Take average so the calories needed for people = 2250 calories

How much calories in 100g of cooked rice? https://www.fatsecret.com.au/calories-nutrition/generic/cooked-rice?portionid=53182&portionamount=100.000#:~:text=There%20are%20135%20calories%20in%20100%20grams%20of%20Cooked%20Rice.

--> 100g of cooked rice is 135 calories

What is weight of a single grain of rice? https://www.bluebulbprojects.com/measureofthings/results.php?comp=weight&unit=gms&amt=0.0044&sort=pr&p=1#:~:text=In%20other%20words%2C%200.0044%20grams%20is%200.210%20times%20the%20weight,is%204.80%20times%20that%20amount.&text=With%20great%20differences%20in%20variety,about%200.021%20grams%20before%20cooking.

--> a single grain of (medium-long) rice weight 0.02g

Conclusion

one grain of rice weight 0.02g

weight of X grain of rice = X * 0.02g = Y(g)

100g of cooked rice provide 135 calories

Total calories of cooked X grain of rice = Y(g) * calories per 100g

# %%
def compute_how_many_days(number_of_grain, number_of_people, calories_needed_per_day = 2200, calories_of_100g_rice = 135, weight_of_one_grain = 0.02):

      total_gram_of_grain = number_of_grain * weight_of_one_grain
      total_calories = total_gram_of_grain * calories_of_100g_rice
      total_calories_needed_per_day = number_of_people * calories_needed_per_day

      days = total_calories / total_calories_needed_per_day

      return days 

number_of_people = 12
day = 120
list_n_grains, list_total_grains = compute_sorori_shinzaemon(day=100)
#List_rice_recieved_each_day = compute_sorori_shinzaemon(day= 120)
#List_total_rice_recieved = compute_sorori_shinzaemon(day=120)
total_grain = list_total_grains[-1]

day_to_live = compute_how_many_days(total_grain, number_of_people)

print("{} people can live in {} days".format(number_of_people,day_to_live))
print("Number of rice grains at this time: {}".format(list_total_grains[-1]))
# Out:
# 100
# ...
